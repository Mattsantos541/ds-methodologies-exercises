# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
telco= pd.read_excel("Matt Santos - Excel_Exercises.xlsx")

# %%
telco
# Out:
#    customer_id  gender  is_senior_citizen partner dependents  phone_service  \
# 0   9732-OUYRN  Female                  0     Yes         No              1
# 1   9447-YPTBX  Female                  0     Yes         No              1
# 2   9432-RUVSL  Female                  0      No         No              1
# 3   9412-ARGBX  Female                  0      No        Yes              1
# 4   9308-ANMVE    Male                  0      No        Yes              1
# 5   9224-VTYID    Male                  0     Yes        Yes              2
# 6   8957-THMOA  Female                  0      No        Yes              1
# 7   8938-UMKPI  Female                  0      No         No              2
# 8   8869-TORSS  Female                  0      No         No              1
# 9   8552-OBVRU  Female                  1     Yes        Yes              1
# 10  8550-XSXUQ    Male                  0     Yes         No              2
# ...

# %%
#Acquire customer_id, monthly_charges, tenure, and total_charges from telco_churn database for all customers 
#with a 2 year contract.
telco.head()
# Out:
#   customer_id  gender  is_senior_citizen partner dependents  phone_service  \
# 0  9732-OUYRN  Female                  0     Yes         No              1
# 1  9447-YPTBX  Female                  0     Yes         No              1
# 2  9432-RUVSL  Female                  0      No         No              1
# 3  9412-ARGBX  Female                  0      No        Yes              1
# 4  9308-ANMVE    Male                  0      No        Yes              1
#
#    internet_service  contract_type               payment_type  \
# 0                 0              1    Credit card (automatic)
# 1                 0              1  Bank transfer (automatic)
# 2                 2              2    Credit card (automatic)
# 3                 2              2               Mailed check
# 4                 1              0           Electronic check
#
#    monthly_charges  ...  has_churned has_phone  has_internet  \
# 0            19.00  ...        False      True         False
# ...

# %%
#customer_id, monthly_charges, tenure, totasl_charges
telco[['monthly_charges','monthly_charges', 'total_charges', 'Length of tenure']].head()
# Out:
#    monthly_charges  monthly_charges  total_charges Length of tenure
# 0            19.00            19.00         918.70  Group5 over49mo
# 1            19.85            19.85         943.10  Group5 over49mo
# 2           102.50           102.50        4904.25  Group5 over49mo
# 3            95.50            95.50        4627.85  Group5 over49mo
# 4            55.30            55.30        2654.05  Group5 over49mo

# %%
#Walk through the steps above using your new dataframe. You may handle the missing values however you feel 
#is appropriate.
telco.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65 entries, 0 to 64
# Data columns (total 24 columns):
# customer_id                65 non-null object
# gender                     65 non-null object
# is_senior_citizen          65 non-null int64
# partner                    65 non-null object
# dependents                 65 non-null object
# phone_service              65 non-null int64
# internet_service           65 non-null int64
# contract_type              65 non-null int64
# payment_type               65 non-null object
# monthly_charges            65 non-null float64
# total_charges              65 non-null float64
# churn                      65 non-null object
# Tenure (months)            65 non-null int64
# is_female                  65 non-null bool
# has_churned                65 non-null bool
# has_phone                  65 non-null bool
# has_internet               65 non-null bool
# partners_dependants        65 non-null int64
# ...

# %%
print(telco.isnull().sum())
# Out:
# customer_id                0
# gender                     0
# is_senior_citizen          0
# partner                    0
# dependents                 0
# phone_service              0
# internet_service           0
# contract_type              0
# payment_type               0
# monthly_charges            0
# total_charges              0
# churn                      0
# Tenure (months)            0
# is_female                  0
# has_churned                0
# has_phone                  0
# has_internet               0
# partners_dependants        0
# Start Date                 0
# Average monthly charges    0
# Contract Type              0
# Phone Service              0
# Internet service           0
# Length of tenure           0
# dtype: int64

# %%
telco.astype('str')
# Out:
#    customer_id  gender is_senior_citizen partner dependents phone_service  \
# 0   9732-OUYRN  Female                 0     Yes         No             1
# 1   9447-YPTBX  Female                 0     Yes         No             1
# 2   9432-RUVSL  Female                 0      No         No             1
# 3   9412-ARGBX  Female                 0      No        Yes             1
# 4   9308-ANMVE    Male                 0      No        Yes             1
# 5   9224-VTYID    Male                 0     Yes        Yes             2
# 6   8957-THMOA  Female                 0      No        Yes             1
# 7   8938-UMKPI  Female                 0      No         No             2
# 8   8869-TORSS  Female                 0      No         No             1
# 9   8552-OBVRU  Female                 1     Yes        Yes             1
# 10  8550-XSXUQ    Male                 0     Yes         No             2
# 11  8313-AFGBW    Male                 0     Yes         No             1
# ...

# %%
pip install vega_datasets
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
from vega_datasets import data
df=data.sf_temps()
df.head()
# Out:
#    temp                date
# 0  47.8 2010-01-01 00:00:00
# 1  47.4 2010-01-01 01:00:00
# 2  46.9 2010-01-01 02:00:00
# 3  46.5 2010-01-01 03:00:00
# 4  46.0 2010-01-01 04:00:00

# %%
pd.to_datetime(df.date)
df = df.set_index('date').sort_index()

# %%
#Resample by the day and take the average temperature. Visualize the average temperature over time.
df.resample('D').agg(['mean'])
# Out:
#                  temp
#                  mean
# date
# 2010-01-01  49.170833
# 2010-01-02  49.304167
# 2010-01-03  49.391667
# 2010-01-04  49.445833
# 2010-01-05  49.491667
# 2010-01-06  49.529167
# 2010-01-07  49.466667
# 2010-01-08  49.475000
# 2010-01-09  49.537500
# 2010-01-10  49.604167
# 2010-01-11  49.675000
# 2010-01-12  49.733333
# 2010-01-13  49.762500
# 2010-01-14  49.866667
# 2010-01-15  49.908333
# 2010-01-16  49.908333
# 2010-01-17  49.950000
# 2010-01-18  49.962500
# 2010-01-19  50.062500
# 2010-01-20  50.137500
# 2010-01-21  50.170833
# 2010-01-22  50.308333
# 2010-01-23  50.354167
# 2010-01-24  50.350000
# 2010-01-25  50.404167
# 2010-01-26  50.495833
# 2010-01-27  50.583333
# 2010-01-28  50.720833
# 2010-01-29  50.808333
# 2010-01-30  50.891667
# ...               ...
# 2010-12-02  52.391667
# 2010-12-03  52.337500
# 2010-12-04  52.279167
# 2010-12-05  52.183333
# 2010-12-06  52.104167
# 2010-12-07  51.987500
# 2010-12-08  51.875000
# 2010-12-09  51.737500
# ...

# %%
#Write the code necessary to visualize the minimum temperature over time.

df.resample('D').agg(['min'])
# Out:
#             temp
#              min
# date
# 2010-01-01  45.8
# 2010-01-02  46.0
# 2010-01-03  46.1
# 2010-01-04  46.1
# 2010-01-05  46.1
# 2010-01-06  46.1
# 2010-01-07  46.0
# 2010-01-08  46.0
# 2010-01-09  46.0
# 2010-01-10  46.1
# 2010-01-11  46.1
# 2010-01-12  46.2
# 2010-01-13  46.1
# 2010-01-14  46.2
# 2010-01-15  46.2
# 2010-01-16  46.2
# 2010-01-17  46.2
# 2010-01-18  46.2
# 2010-01-19  46.4
# 2010-01-20  46.4
# 2010-01-21  46.5
# 2010-01-22  46.6
# 2010-01-23  46.6
# 2010-01-24  46.5
# 2010-01-25  46.5
# 2010-01-26  46.6
# 2010-01-27  46.6
# 2010-01-28  46.7
# 2010-01-29  46.7
# 2010-01-30  46.8
# ...          ...
# 2010-12-02  48.6
# 2010-12-03  48.6
# 2010-12-04  48.6
# 2010-12-05  48.5
# 2010-12-06  48.5
# 2010-12-07  48.4
# 2010-12-08  48.3
# 2010-12-09  48.3
# 2010-12-10  48.1
# 2010-12-11  48.0
# 2010-12-12  47.9
# 2010-12-13  47.7
# 2010-12-14  47.5
# 2010-12-15  47.3
# 2010-12-16  46.9
# 2010-12-17  46.7
# 2010-12-18  46.4
# 2010-12-19  46.1
# 2010-12-20  46.0
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rc('figure', figsize=(12, 9))

# df.plot()
df.resample('M').min().plot()

# %%
#Write the code necessary to visualize the maximum temperature over time.
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rc('figure', figsize=(12, 9))

# df.plot()
df.resample('D').max().plot()

# %%
#Which month is the coldest, on average?
df.resample('M').agg(['mean'])
# Out:
#                  temp
#                  mean
# date
# 2010-01-31  49.984140
# 2010-02-28  52.243899
# 2010-03-31  53.956528
# 2010-04-30  55.633056
# 2010-05-31  57.970968
# 2010-06-30  60.444722
# 2010-07-31  61.765457
# 2010-08-31  62.405376
# 2010-09-30  62.487083
# 2010-10-31  60.253091
# 2010-11-30  55.185139
# 2010-12-31  50.498253

# %%
#Which month has the highest average temperature?
df.resample('M').agg(['mean'])
# Out:
#                  temp
#                  mean
# date
# 2010-01-31  49.984140
# 2010-02-28  52.243899
# 2010-03-31  53.956528
# 2010-04-30  55.633056
# 2010-05-31  57.970968
# 2010-06-30  60.444722
# 2010-07-31  61.765457
# 2010-08-31  62.405376
# 2010-09-30  62.487083
# 2010-10-31  60.253091
# 2010-11-30  55.185139
# 2010-12-31  50.498253

# %%
#Resample by the day and calculate the min and max temp for the day (Hint: .agg(['min', 'max'])). Use this resampled dataframe to calculate the change in temperature for the day. Which month has the highest daily temperature variability?
df.resample('D').agg(['min', 'mean', 'max', 'count'])
# Out:
#             temp
#              min       mean   max count
# date
# 2010-01-01  45.8  49.170833  53.3    24
# 2010-01-02  46.0  49.304167  53.4    24
# 2010-01-03  46.1  49.391667  53.5    24
# 2010-01-04  46.1  49.445833  53.6    24
# 2010-01-05  46.1  49.491667  53.8    24
# 2010-01-06  46.1  49.529167  53.8    24
# 2010-01-07  46.0  49.466667  53.8    24
# 2010-01-08  46.0  49.475000  53.9    24
# 2010-01-09  46.0  49.537500  54.0    24
# 2010-01-10  46.1  49.604167  54.1    24
# 2010-01-11  46.1  49.675000  54.2    24
# 2010-01-12  46.2  49.733333  54.3    24
# 2010-01-13  46.1  49.762500  54.4    24
# 2010-01-14  46.2  49.866667  54.5    24
# 2010-01-15  46.2  49.908333  54.6    24
# 2010-01-16  46.2  49.908333  54.6    24
# 2010-01-17  46.2  49.950000  54.7    24
# 2010-01-18  46.2  49.962500  54.7    24
# 2010-01-19  46.4  50.062500  54.8    24
# 2010-01-20  46.4  50.137500  54.9    24
# 2010-01-21  46.5  50.170833  54.9    24
# 2010-01-22  46.6  50.308333  55.2    24
# ...

# %%
#Bonus: Visualize the daily min, average, and max temperature over time on a single line plot, i.e. the min, average, and maximum temperature should be 3 seperate lines.
ax = df.plot()
df.resample('D').mean().plot(ax=ax)
df.resample('D').min().plot(ax=ax)
df.resample('D').max().plot(ax=ax)

# %%
from vega_datasets import data
pd.to_datetime('Nov:19', format='%b:%y')


weather = data.seattle_weather()
weather1 = weather[['date', 'precipitation']]
weather1 = weather.set_index('date')
weather1
# Out:
#             precipitation  temp_max  temp_min  wind  weather
# date
# 2012-01-01            0.0      12.8       5.0   4.7  drizzle
# 2012-01-02           10.9      10.6       2.8   4.5     rain
# 2012-01-03            0.8      11.7       7.2   2.3     rain
# 2012-01-04           20.3      12.2       5.6   4.7     rain
# 2012-01-05            1.3       8.9       2.8   6.1     rain
# 2012-01-06            2.5       4.4       2.2   2.2     rain
# 2012-01-07            0.0       7.2       2.8   2.3     rain
# 2012-01-08            0.0      10.0       2.8   2.0      sun
# 2012-01-09            4.3       9.4       5.0   3.4     rain
# 2012-01-10            1.0       6.1       0.6   3.4     rain
# 2012-01-11            0.0       6.1      -1.1   5.1      sun
# 2012-01-12            0.0       6.1      -1.7   1.9      sun
# 2012-01-13            0.0       5.0      -2.8   1.3      sun
# 2012-01-14            4.1       4.4       0.6   5.3     snow
# ...

# %%
#Which year and month combination has the highest amount of precipitation
weather.groupby(weather.index.month).mean()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-5bc2343ec507> in <module>
#       1 #Which year and month combination has the highest amount of precipitation
# ----> 2 weather.groupby(weather.index.month).mean()
#
# AttributeError: 'RangeIndex' object has no attribute 'month'

# %%
#Visualize the amount of monthly precipitation over time.
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rc('figure', figsize=(12, 9))

# df.plot()
weather.resample('M').mean().plot()

# %%
weather2 = weather[['date', 'wind']]
weather2 = weather.set_index('date')
weather2
#%matplotlib inline
#import matplotlib.pyplot as plt
#plt.rc('figure', figsize=(12, 9))

# df.plot()
#df.resample('M').mean().plot()

# %%
#Visualize the amount of wind over time. Choose a time interval you think is appropriate.
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rc('figure', figsize=(12, 9))

# df.plot()
weather2.resample('M').mean().plot()
print(df.wind.resample("M").sum().idxmax().month)
print(df.wind.resample('M').sum().idxmax().year)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-4e5b4aae5c66> in <module>
#       5
#       6 # df.plot()
# ----> 7 weather2.resample('M').mean().plot()
#       8 print(df.wind.resample("M").sum().idxmax().month)
#       9 print(df.wind.resample('M').sum().idxmax().year)
#
# NameError: name 'weather2' is not defined

# %%
#What's the sunniest year? (Hint: which day has the highest number of days where weather == sun?)

# %%
#data.flights_20k()
df_flights= data('flights_20k')

# %%
df_flights = df_flights.set_index('date')

# %% [markdown]
# Convert any negative delays to 0.
# Which hour of the day has the highest average delay?
# Does the day of the week make a difference in the delay amount?
# Does the month make a difference in the delay amount?

# %%
df_flights.delay[df_flights.delay<0]
# Out:
# date
# 2001-01-31 16:40:00    -5
# 2001-01-10 21:00:00   -15
# 2001-03-30 21:45:00    -2
# 2001-01-27 07:00:00   -13
# 2001-01-02 11:40:00    -1
# 2001-03-07 21:15:00    -3
# 2001-02-11 17:00:00    -6
# 2001-02-26 06:50:00    -2
# 2001-03-20 09:50:00   -12
# 2001-03-22 13:20:00    -6
# 2001-03-29 21:55:00    -7
# 2001-03-16 07:30:00   -11
# 2001-03-13 17:30:00   -10
# 2001-03-14 18:12:00    -2
# 2001-03-12 17:25:00    -4
# 2001-01-30 18:35:00    -7
# 2001-02-07 11:30:00    -5
# 2001-01-07 08:40:00    -8
# 2001-03-25 12:40:00    -8
# 2001-03-27 14:55:00    -3
# 2001-03-13 18:30:00    -9
# 2001-01-15 11:00:00    -7
# 2001-01-14 07:00:00   -14
# 2001-01-30 07:20:00   -10
# 2001-01-15 10:05:00   -10
# 2001-03-24 12:00:00    -2
# 2001-01-31 07:10:00    -2
# 2001-03-10 18:25:00   -22
# 2001-01-09 16:45:00    -5
# 2001-03-10 13:50:00   -10
#                        ..
# 2001-03-03 11:25:00    -3
# 2001-02-04 16:35:00    -5
# 2001-03-01 07:20:00   -10
# 2001-01-05 10:00:00    -2
# ...

# %%
from vega_datasets import data
data.iowa_electricity()
# Out:
#          year          source  net_generation
# 0  2001-01-01    Fossil Fuels           35361
# 1  2002-01-01    Fossil Fuels           35991
# 2  2003-01-01    Fossil Fuels           36234
# 3  2004-01-01    Fossil Fuels           36205
# 4  2005-01-01    Fossil Fuels           36883
# 5  2006-01-01    Fossil Fuels           37014
# 6  2007-01-01    Fossil Fuels           41389
# 7  2008-01-01    Fossil Fuels           42734
# 8  2009-01-01    Fossil Fuels           38620
# 9  2010-01-01    Fossil Fuels           42750
# 10 2011-01-01    Fossil Fuels           39361
# 11 2012-01-01    Fossil Fuels           37379
# 12 2013-01-01    Fossil Fuels           34873
# 13 2014-01-01    Fossil Fuels           35250
# 14 2015-01-01    Fossil Fuels           32319
# 15 2016-01-01    Fossil Fuels           28437
# 16 2017-01-01    Fossil Fuels           29329
# 17 2001-01-01  Nuclear Energy            3853
# 18 2002-01-01  Nuclear Energy            4574
# ...

# %%
#For each row, calculate the percentage of the year's total that energy source provided.
